# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # <center> Stackoverflow </center>
# ## <center>  Tags for  </center>
# ### <center>   Questions and Answers </center>
#
#
# <br>
#
# </div>

# %% [markdown]
# # Tags
#
# ### Q&A?
#
# A tag is a keyword or label that categorizes your question with other, similar questions. Using the right tags makes it easier for others to find and answer your question.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <br>
# Following are official URLs for stackoverflow
#
#
# ## References:
#
# - https://stackoverflow.com/tags
# - https://api.stackexchange.com/docs
#
#
#
# </div>
#
#
# <hr style="border:5px solid orange"> </hr>

# %% [markdown]
# <br><br><br><br>
#
# # How to find Stackoverflow Questions and answeres?
#
# <br><br>
#
# ### Questions/Answers For different tags Docker, Kubernetes, Python, GoLang, Angular,  React, etc.
#
#
#
# <hr style="border:5px solid orange"> </hr>

# %% [markdown]
# Create an environment for Python 3.9:
#
# To install python 3.9 on your PC you will need to run the following command in your terminal:
#
#
# conda create -n py39 python=3.9
#
#
# This will create a new environment from which you can open your jupyter notebook. To verify if the right version of python is installed on your conda, open the Anaconda-navigator (this would have been installed once you finish installing anaconda in Step 1).
#
# Once you open the Anaconda Navigator, click on the Environments tab on the Left navigation bar and check if it has two environments installed:
#
# 1.	The base or the root environment where Python 3.9 is installed
# 2.	The py39 environment where we will be running our code
# 3.  Open a terminal from the py39 tab
#
# Step 3: Install dependencies:
#
# The following pip commands needs to execute to install all the dependencies needed by out notebook. Type the following commands in the terminal one after another:
#
# 1.	pip install jupyter
# once installed proceed to execute the next line
#
# 3.	pip install stackapi
# once installed proceed to execute the next line
#
# 4.	pip install stackpy
# once installed proceed to execute the next line
#
# 5.	pip install pandas
# once installed proceed to execute the next line
#
# 7.	pip install matplotlib --default-timeout=100 future
# once installed proceed to execute the next line
#
# 8.	pip install datetime
# once installed proceed to execute the next line

# %%
# Installation of required libraries using pip. PIP is a package manager for Python packages, or modules.
# !pip install jupyter
# !pip install stackapi
# !pip install stackpy
# !pip install pandas
# !pip install sklearn
# !pip install matplotlib --default-timeout=100 future
# !pip install datetime

# %%
# Import all the required packages
import pandas as pd
import numpy as np
from stackapi import StackAPI
from dateutil.relativedelta import relativedelta
import datetime
import numpy as np
import time
from datetime import timedelta
from datetime import datetime
import json
import requests


# matplotlib for plotting graphs
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings

deprecation._PRINT_DEPRECATION_WARNINGS = False
warnings.filterwarnings('ignore')

# %% [markdown]
# # Pull past-year data from stackexchange api

# %% [markdown]
# <!-- # #
# # today = datetime.today()
# # one_year = str(int(datetime.timestamp(today - relativedelta(years=1))))
# # today = str(int(datetime.timestamp(today)))
# # questions_data = []
#
# # tagged = 'docker'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
#
# # tagged = 'kubernetes'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
#
# # tagged = 'python'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
#
# # tagged = 'golang'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
# # tagged = 'angular'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
#
# # tagged = 'react'
# # page = 1
# # question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# # questions = json.loads(question.text)
# # if "items" in questions:
# #     questions_data += questions['items']
# # while 'has_more' in questions and questions['has_more']:
# #     time.sleep(3)
# #     page += 1
# #     question = requests.get('https://api.stackexchange.com/2.3/questions?page=' + str(page) + '&fromdate=' + one_year + '&todate=' + today + '&order=desc&sort=activity&tagged=' + tagged + '&site=stackoverflow')
# #     questions = json.loads(question.text)
# #     if "items" in questions:
# #         questions_data += questions['items']
#
# # with open('output.txt', 'w') as filehandle:
# #     json.dump(questions_data, filehandle) -->

# %%
# Defining column names according to tags (keyword) found in stackoverflow questions
df = pd.DataFrame(columns =['docker', 'kubernetes', 'python', 'golang', 'angular', 'react', 'timestamp'])

docker = 0
kubernetes = 0
python = 0
golang = 0
angular = 0
react = 0

# Please generate your key from StackExchangeApi
key = 'ADD_YOUR_API_KEY_HERE'

# %% [markdown]
# ## Docker

# %%
questions_data = []
tagged = 'docker'
page = 1
fromdate = str(int(datetime.timestamp(datetime.today() - relativedelta(months=13))))
todate = str(int(datetime.timestamp(datetime.today() - relativedelta(months=0))))

question = requests.get('https://api.stackexchange.com/2.3/questions?pagesize=100&page=' + str(page) + '&sort=activity&fromdate=' + fromdate + '&todate=' + todate + '&order=desc&tagged=' + tagged + '&site=stackoverflow&key=' + key)
questions = json.loads(question.text)
if "items" in questions:
    questions_data += questions['items']
    
while 'has_more' in questions and questions['has_more']:
    if page%98 == 0:
        time.sleep(300)
    time.sleep(1)
    page += 1
    question = requests.get('https://api.stackexchange.com/2.3/questions?pagesize=100&page=' + str(page) + '&sort=activity&fromdate=' + fromdate + '&todate=' + todate + '&order=desc&tagged=' + tagged + '&site=stackoverflow&key=' + key)
    questions = json.loads(question.text)
    if "items" in questions:
        questions_data += questions['items']
        
for question in questions_data:
    docker = docker + 1
    df2 = pd.DataFrame({'docker': [1], 'timestamp' : [question['creation_date']]})
    df = pd.concat([df, df2], ignore_index = True, axis = 0)

# %%
questions
# Out:
# {'items': [{'tags': ['docker', 'docker-compose', 'amazon-ecs'],
#    'owner': {'account_id': 2710453,
#     'reputation': 1277,
#     'user_id': 2339034,
#     'user_type': 'registered',
#     'accept_rate': 67,
#     'profile_image': 'https://i.stack.imgur.com/BWdZJ.jpg?s=256&g=1',
#     'display_name': 'PowerMan2015',
#     'link': 'https://stackoverflow.com/users/2339034/powerman2015'},
#    'is_answered': False,
#    'view_count': 170,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645438819,
#    'creation_date': 1645438819,
#    'question_id': 71204588,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71204588/docker-compose-f-docker-compose-dev-yaml-up-fails-without-error-using-ecs-conte',
#    'title': 'Docker compose -f docker-compose-dev.yaml up fails without error using ecs context'},
#   {'tags': ['docker', 'continuous-integration', 'github-actions'],
#    'owner': {'account_id': 23530650,
#     'reputation': 51,
#     'user_id': 17576352,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7133549f11e041d983c5db9ac31ced5f?s=256&d=identicon&r=PG',
#     'display_name': 'springboot',
#     'link': 'https://stackoverflow.com/users/17576352/springboot'},
#    'is_answered': True,
#    'view_count': 2152,
#    'answer_count': 1,
#    'score': 3,
#    'last_activity_date': 1645437805,
#    'creation_date': 1645427655,
#    'last_edit_date': 1645437067,
#    'question_id': 71202445,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71202445/error-buildx-failed-with-error-invalid-tag-docker-pkg-github-com-myself-cmms',
#    'title': 'Error: buildx failed with: error: invalid tag &quot;docker.pkg.github.com/myself/cmms:&quot;: invalid reference format'},
#   {'tags': ['node.js', 'docker', 'dockerfile', 'workdir'],
#    'owner': {'account_id': 23014209,
#     'reputation': 539,
#     'user_id': 17136258,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/R0zAj.jpg?s=256&g=1',
#     'display_name': 'Test',
#     'link': 'https://stackoverflow.com/users/17136258/test'},
#    'is_answered': True,
#    'view_count': 790,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1645437165,
#    'creation_date': 1645432719,
#    'question_id': 71203321,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71203321/no-such-file-or-directory-in-copying-a-file',
#    'title': 'No such file or directory in copying a file'},
#   {'tags': ['docker', 'docker-compose', 'sails.js'],
#    'owner': {'account_id': 4352536,
#     'reputation': 5,
#     'user_id': 3552353,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/100006071652838/picture?type=large',
#     'display_name': 'user3552353',
#     'link': 'https://stackoverflow.com/users/3552353/user3552353'},
#    'is_answered': False,
#    'view_count': 57,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645435130,
#    'creation_date': 1645435130,
#    'question_id': 71203795,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71203795/encountered-an-error-when-attempting-to-requiresails',
#    'title': 'Encountered an error when attempting to require(&#39;sails);'},
#   {'tags': ['docker', 'docker-build'],
#    'owner': {'account_id': 20336972,
#     'reputation': 1263,
#     'user_id': 14917411,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-GSB5j6aNb7g/AAAAAAAAAAI/AAAAAAAAAAA/AMZuuckHoyaoimzqll4YF9FPPCsUHMqRrA/s96-c/photo.jpg?sz=256',
#     'display_name': 'Sabo Boz',
#     'link': 'https://stackoverflow.com/users/14917411/sabo-boz'},
#    'is_answered': True,
#    'view_count': 209,
#    'accepted_answer_id': 71203370,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1645434596,
#    'creation_date': 1645430650,
#    'question_id': 71202967,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71202967/how-to-create-a-docker-image-container-from-two-existing-containers',
#    'title': 'how to create a docker image/container from two existing containers'},
#   {'tags': ['docker', 'nginx'],
#    'owner': {'account_id': 22442088,
#     'reputation': 11,
#     'user_id': 16646452,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJw-F9RJ0GAb8csKRcExK6HxReZDdhpdiAwMe58=k-s256',
#     'display_name': 'Jacky Yu',
#     'link': 'https://stackoverflow.com/users/16646452/jacky-yu'},
#    'is_answered': True,
#    'view_count': 426,
#    'answer_count': 2,
#    'score': -1,
#    'last_activity_date': 1645433605,
#    'creation_date': 1645424151,
#    'question_id': 71201920,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71201920/nginx-and-springboot-in-docker-container-got-502-bad-gateway',
#    'title': 'NGINX and SPRINGBOOT in DOCKER container GOT 502 Bad Gateway'},
#   {'tags': ['java', 'mysql', 'linux', 'docker'],
#    'owner': {'account_id': 24326943,
#     'reputation': 1,
#     'user_id': 18266363,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJyPTEeJ4PnsGsiMSVhFuEHIj4QrmvoypPf_8G03=k-s256',
#     'display_name': 'raxcl',
#     'link': 'https://stackoverflow.com/users/18266363/raxcl'},
#    'is_answered': False,
#    'view_count': 13,
#    'closed_date': 1645432930,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645432879,
#    'creation_date': 1645432262,
#    'last_edit_date': 1645432879,
#    'question_id': 71203254,
#    'link': 'https://stackoverflow.com/questions/71203254/java-mysqldump-couldnt-find-table',
#    'closed_reason': 'Duplicate',
#    'title': 'java: mysqldump: Couldn&#39;t find table: &quot;&gt;&quot;'},
#   {'tags': ['docker', 'kubernetes', 'openshift', 'hashicorp-vault'],
#    'owner': {'account_id': 24326352,
#     'reputation': 1,
#     'user_id': 18265851,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AATXAJxEZFBIbPZAC557mnOz2FKc63CM-c24ThuLqv6X=k-s256',
#     'display_name': 'Shay Vaintrob',
#     'link': 'https://stackoverflow.com/users/18265851/shay-vaintrob'},
#    'is_answered': False,
#    'view_count': 417,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1645430692,
#    'creation_date': 1645428576,
#    'question_id': 71202599,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71202599/how-to-set-env-vars-from-init-container',
#    'title': 'How to set env vars from init container'},
#   {'tags': ['python', 'python-3.x', 'docker', 'flask', 'dockerfile'],
#    'owner': {'account_id': 5643165,
#     'reputation': 672,
#     'user_id': 4466240,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://i.stack.imgur.com/AOmVU.jpg?s=256&g=1',
#     'display_name': 'Ritik Saxena',
#     'link': 'https://stackoverflow.com/users/4466240/ritik-saxena'},
#    'is_answered': False,
#    'view_count': 90,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645425168,
#    'creation_date': 1645423352,
#    'last_edit_date': 1645425168,
#    'question_id': 71201827,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71201827/unable-to-load-flaskenv-into-docker',
#    'title': 'Unable to load .flaskenv into Docker'},
#   {'tags': ['javascript', 'docker', 'websocket', 'docker-compose', 'next.js'],
#    'owner': {'account_id': 5805882,
#     'reputation': 195,
#     'user_id': 4578512,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://graph.facebook.com/335938873273166/picture?type=large',
#     'display_name': 'Hiro',
#     'link': 'https://stackoverflow.com/users/4578512/hiro'},
#    'is_answered': False,
#    'view_count': 135,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645425080,
#    'creation_date': 1645425080,
#    'question_id': 71202051,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71202051/nextjs-websocket-proxy-to-server-through-docker-dns',
#    'title': 'NextJS websocket proxy(?) to server through docker DNS'},
#   {'tags': ['sql-server', 'macos', 'docker', 'parallels'],
#    'owner': {'account_id': 12943813,
#     'reputation': 59,
#     'user_id': 9358744,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/96b078dad02e13705e74068fa9a540aa?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Vergil',
#     'link': 'https://stackoverflow.com/users/9358744/vergil'},
#    'is_answered': False,
#    'view_count': 984,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645418412,
#    'creation_date': 1645418412,
#    'question_id': 71201300,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71201300/connecting-to-sql-server-in-parallels-from-docker-on-mac',
#    'title': 'Connecting to SQL Server in Parallels from Docker on Mac'},
#   {'tags': ['java', 'spring', 'spring-boot', 'docker', 'kubernetes'],
#    'owner': {'account_id': 11414117,
#     'reputation': 135,
#     'user_id': 8367387,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/891ebf094426c3cd1821ffaf4ec99121?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'raman bhadauria',
#     'link': 'https://stackoverflow.com/users/8367387/raman-bhadauria'},
#    'is_answered': False,
#    'view_count': 398,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645417888,
#    'creation_date': 1645417888,
#    'question_id': 71201257,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71201257/how-to-use-environment-variables-of-a-project-in-the-java-library',
#    'title': 'How to use environment variables of a project in the java library?'},
#   {'tags': ['docker', 'docker-compose'],
#    'owner': {'account_id': 6781555,
#     'reputation': 3,
#     'user_id': 5221603,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/92bab8d66c37b24b463c2315e96bfb88?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'JMullica',
#     'link': 'https://stackoverflow.com/users/5221603/jmullica'},
#    'is_answered': False,
#    'view_count': 824,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645412802,
#    'creation_date': 1645412802,
#    'question_id': 71200785,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71200785/docker-compose-exited-with-code-1-errno-2-name-or-service-not-known',
#    'title': 'docker-compose exited with code 1 Errno 2 Name or Service not known'},
#   {'tags': ['docker', 'dockerfile'],
#    'owner': {'account_id': 4480896,
#     'reputation': 3560,
#     'user_id': 3644991,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://i.stack.imgur.com/UnPaN.jpg?s=256&g=1',
#     'display_name': 'Luke Schlangen',
#     'link': 'https://stackoverflow.com/users/3644991/luke-schlangen'},
#    'is_answered': True,
#    'view_count': 2224,
#    'accepted_answer_id': 71200690,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1645411567,
#    'creation_date': 1645410943,
#    'question_id': 71200635,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71200635/can-i-remove-run-apk-add-no-cache-python2-g-make-from-my-dockerfile',
#    'title': 'Can I remove `RUN apk add --no-cache python2 g++ make` from my Dockerfile?'},
#   {'tags': ['docker',
#     'asp.net-web-api',
#     '.net-6.0',
#     'docker-image',
#     'docker-build'],
#    'owner': {'account_id': 11400898,
#     'reputation': 588,
#     'user_id': 8357883,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/879779078835853/picture?type=large',
#     'display_name': 'Shpend Palushi',
#     'link': 'https://stackoverflow.com/users/8357883/shpend-palushi'},
#    'is_answered': True,
#    'view_count': 368,
#    'accepted_answer_id': 71199003,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1645397585,
#    'creation_date': 1645385910,
#    'last_edit_date': 1645388945,
#    'question_id': 71198085,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71198085/creating-docker-image-for-a-dotnet-6-application-type-already-defines-a-mem',
#    'title': 'Creating Docker image for a dotnet 6 application - Type &#39;&#39; already defines a member called &#39;&#39; with the same parameter types'},
#   {'tags': ['docker'],
#    'owner': {'account_id': 88832,
#     'reputation': 2132,
#     'user_id': 245493,
#     'user_type': 'registered',
#     'accept_rate': 47,
#     'profile_image': 'https://www.gravatar.com/avatar/d1dabc2bd131166c5c8185f30e6c2b03?s=256&d=identicon&r=PG',
#     'display_name': 'Akasha',
#     'link': 'https://stackoverflow.com/users/245493/akasha'},
#    'is_answered': True,
#    'view_count': 64,
#    'accepted_answer_id': 71199311,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1645395526,
#    'creation_date': 1645394850,
#    'question_id': 71199235,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71199235/can-i-use-docker-arguments-in-the-from-flag-of-a-docker-copy-statement',
#    'title': 'Can I use Docker arguments in the `from` flag of a Docker COPY statement?'},
#   {'tags': ['mongodb', 'docker', 'kubernetes'],
#    'owner': {'account_id': 24322560,
#     'reputation': 21,
#     'user_id': 18262684,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bd1150b9fe0f5e3497d307327d7ca034?s=256&d=identicon&r=PG',
#     'display_name': 'KozlovNik',
#     'link': 'https://stackoverflow.com/users/18262684/kozlovnik'},
#    'is_answered': False,
#    'view_count': 151,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645391114,
#    'creation_date': 1645391114,
#    'question_id': 71198788,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71198788/connecting-to-mongodb-replica-set-outside-kubernetes-cluster',
#    'title': 'Connecting to mongodb replica set outside kubernetes cluster'},
#   {'tags': ['python', 'docker', 'debian', 'distroless', 'pyrender'],
#    'owner': {'account_id': 1074365,
#     'reputation': 3915,
#     'user_id': 1072825,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/a27932ed81093b975e0b2619367cce95?s=256&d=identicon&r=PG',
#     'display_name': 'Pavan K',
#     'link': 'https://stackoverflow.com/users/1072825/pavan-k'},
#    'is_answered': True,
#    'view_count': 434,
#    'accepted_answer_id': 71198290,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1645387973,
#    'creation_date': 1645377328,
#    'last_edit_date': 1645387973,
#    'question_id': 71196831,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71196831/container-multi-stage-build-with-pyrender-for-distroless',
#    'title': 'Container multi stage build with pyrender for distroless'},
#   {'tags': ['python', 'node.js', 'docker', 'docker-compose', 'dockerfile'],
#    'owner': {'account_id': 23014209,
#     'reputation': 539,
#     'user_id': 17136258,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/R0zAj.jpg?s=256&g=1',
#     'display_name': 'Test',
#     'link': 'https://stackoverflow.com/users/17136258/test'},
#    'is_answered': True,
#    'view_count': 3911,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1645384946,
#    'creation_date': 1645380931,
#    'question_id': 71197350,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71197350/use-python-and-node-js-in-the-same-dockerfile-and-create-one-image-that-i-cloud',
#    'title': 'Use Python and Node.js in the same Dockerfile and create one image that I cloud use both'},
#   {'tags': ['docker', 'nginx', 'phpmyadmin'],
#    'owner': {'account_id': 23194353,
#     'reputation': 41,
#     'user_id': 17290208,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/FwQyv.jpg?s=256&g=1',
#     'display_name': 'Katelyn',
#     'link': 'https://stackoverflow.com/users/17290208/katelyn'},
#    'is_answered': False,
#    'view_count': 487,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645379443,
#    'creation_date': 1645379443,
#    'question_id': 71197130,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71197130/phpmyadmin-cant-connect-to-mariadb-in-docker',
#    'title': 'phpmyadmin can&#39;t connect to mariadb in docker'},
#   {'tags': ['docker', 'raspberry-pi', 'nfs'],
#    'owner': {'account_id': 4280580,
#     'reputation': 1,
#     'user_id': 3500084,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'TurkeyDev',
#     'link': 'https://stackoverflow.com/users/3500084/turkeydev'},
#    'is_answered': False,
#    'view_count': 80,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1645377543,
#    'creation_date': 1645377543,
#    'question_id': 71196870,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71196870/running-docker-on-a-netbooted-raspberry-pi',
#    'title': 'Running Docker on a Netbooted Raspberry Pi'},
#   {'tags': ['django', 'docker', 'nginx', 'gunicorn', 'dokku'],
#    'owner': {'account_id': 3747607,
#     'reputation': 2862,
#     'user_id': 9724750,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5ab06fab3d1d9317889437631ef0ccce?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Neil',
#     'link': 'https://stackoverflow.com/users/9724750/neil'},
#    'is_answered': False,
#    'view_count': 80,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1645376996,
#    'creation_date': 1645376996,
#    'question_id': 71196784,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71196784/django-in-docker-on-nginx-request-to-self-fails-when-in-the-context-of-another-r',
#    'title': 'Django in Docker on Nginx request to self fails when in the context of another request'}],
#  'has_more': False,
#  'quota_max': 10000,
#  'quota_remaining': 9780}
